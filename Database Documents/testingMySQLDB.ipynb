# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/noelluna/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (8.0.23)
# Requirement already satisfied: protobuf>=3.0.0 in /Users/noelluna/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from mysql-connector-python) (3.15.4)
# Requirement already satisfied: six>=1.9 in /Users/noelluna/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from protobuf>=3.0.0->mysql-connector-python) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import config as cnf

mydb = mysql.connector.connect(
  host="final-project.cdjfmodwzyq7.us-east-2.rds.amazonaws.com",
  user=cnf.USERNAME,
  password=cnf.PW,
  database="final_project"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM clean_diabetes")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (881138, 2003, 'US', 'Age', '18-24 years', 'Crude Prevalence', 13.4, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (881139, 2003, 'US', 'Age', '25-34 years', 'Crude Prevalence', 17.3, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (881140, 2003, 'US', 'Age', '35-44 years', 'Crude Prevalence', 20.0, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (881141, 2003, 'US', 'Age', '45-54 years', 'Crude Prevalence', 18.9, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (881142, 2003, 'US', 'Age', '55-64 years', 'Crude Prevalence', 13.2, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (881143, 2003, 'US', 'Age', '65+ years', 'Crude Prevalence', 17.1, '**', 'Median value reported with no confidence intervals', None, None, 54.0, 'Overall', 'Overall', 'AGE', 1.0, 1.0)
# (880936, 2003, 'UW', 'Age', '18-24 years', 'Crude Prevalence', 13.3, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (880937, 2003, 'UW', 'Age', '25-34 years', 'Crude Prevalence', 17.2, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (880938, 2003, 'UW', 'Age', '35-44 years', 'Crude Prevalence', 19.9, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (880939, 2003, 'UW', 'Age', '45-54 years', 'Crude Prevalence', 18.9, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (880940, 2003, 'UW', 'Age', '55-64 years', 'Crude Prevalence', 13.2, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (880941, 2003, 'UW', 'Age', '65+ years', 'Crude Prevalence', 17.1, '**', 'Median value reported with no confidence intervals', None, None, 51.0, 'Overall', 'Overall', 'AGE', 2.0, 2.0)
# (877987, 2003, 'AL', 'Age', '18-24 years', 'Crude Prevalence', 13.5, None, None, 11.6, 15.4, 231.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (877988, 2003, 'AL', 'Age', '25-34 years', 'Crude Prevalence', 17.2, None, None, 15.7, 18.7, 509.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (877989, 2003, 'AL', 'Age', '35-44 years', 'Crude Prevalence', 19.3, None, None, 17.7, 20.9, 584.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (877990, 2003, 'AL', 'Age', '45-54 years', 'Crude Prevalence', 18.6, None, None, 17.1, 20.1, 675.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (877991, 2003, 'AL', 'Age', '55-64 years', 'Crude Prevalence', 13.4, None, None, 12.2, 14.6, 598.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (877992, 2003, 'AL', 'Age', '65+ years', 'Crude Prevalence', 17.9, None, None, 16.6, 19.2, 742.0, 'Overall', 'Overall', 'AGE', 3.0, 3.0)
# (880104, 2003, 'AK', 'Age', '18-24 years', 'Crude Prevalence', 14.0, None, None, 11.9, 16.1, 227.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (880105, 2003, 'AK', 'Age', '25-34 years', 'Crude Prevalence', 18.4, None, None, 16.3, 20.5, 491.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (880106, 2003, 'AK', 'Age', '35-44 years', 'Crude Prevalence', 23.4, None, None, 21.2, 25.6, 633.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (880107, 2003, 'AK', 'Age', '45-54 years', 'Crude Prevalence', 23.2, None, None, 20.9, 25.5, 661.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (880108, 2003, 'AK', 'Age', '55-64 years', 'Crude Prevalence', 11.7, None, None, 10.2, 13.2, 372.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (880109, 2003, 'AK', 'Age', '65+ years', 'Crude Prevalence', 9.3, None, None, 7.9, 10.7, 281.0, 'Overall', 'Overall', 'AGE', 4.0, 4.0)
# (882556, 2003, 'AZ', 'Age', '18-24 years', 'Crude Prevalence', 12.7, None, None, 10.2, 15.2, 196.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (882557, 2003, 'AZ', 'Age', '25-34 years', 'Crude Prevalence', 19.2, None, None, 17.0, 21.4, 453.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (882558, 2003, 'AZ', 'Age', '35-44 years', 'Crude Prevalence', 19.6, None, None, 17.5, 21.7, 559.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (882559, 2003, 'AZ', 'Age', '45-54 years', 'Crude Prevalence', 17.3, None, None, 15.4, 19.2, 638.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (882560, 2003, 'AZ', 'Age', '55-64 years', 'Crude Prevalence', 12.8, None, None, 11.4, 14.2, 556.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (882561, 2003, 'AZ', 'Age', '65+ years', 'Crude Prevalence', 18.4, None, None, 16.7, 20.1, 833.0, 'Overall', 'Overall', 'AGE', 5.0, 5.0)
# (884459, 2003, 'AR', 'Age', '18-24 years', 'Crude Prevalence', 13.4, None, None, 11.8, 15.0, 280.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (884460, 2003, 'AR', 'Age', '25-34 years', 'Crude Prevalence', 17.0, None, None, 15.7, 18.3, 594.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (884461, 2003, 'AR', 'Age', '35-44 years', 'Crude Prevalence', 18.8, None, None, 17.4, 20.2, 737.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (884462, 2003, 'AR', 'Age', '45-54 years', 'Crude Prevalence', 17.8, None, None, 16.6, 19.0, 894.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (884463, 2003, 'AR', 'Age', '55-64 years', 'Crude Prevalence', 13.7, None, None, 12.7, 14.7, 735.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (884464, 2003, 'AR', 'Age', '65+ years', 'Crude Prevalence', 19.3, None, None, 18.1, 20.5, 965.0, 'Overall', 'Overall', 'AGE', 6.0, 6.0)
# (886749, 2003, 'CA', 'Age', '18-24 years', 'Crude Prevalence', 13.3, None, None, 11.9, 14.7, 377.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (886750, 2003, 'CA', 'Age', '25-34 years', 'Crude Prevalence', 19.9, None, None, 18.5, 21.3, 793.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (886751, 2003, 'CA', 'Age', '35-44 years', 'Crude Prevalence', 21.5, None, None, 20.1, 22.9, 935.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (886752, 2003, 'CA', 'Age', '45-54 years', 'Crude Prevalence', 18.5, None, None, 17.1, 19.9, 847.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (886753, 2003, 'CA', 'Age', '55-64 years', 'Crude Prevalence', 11.9, None, None, 10.8, 13.0, 643.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (886754, 2003, 'CA', 'Age', '65+ years', 'Crude Prevalence', 14.9, None, None, 13.8, 16.0, 880.0, 'Overall', 'Overall', 'AGE', 7.0, 7.0)
# (888858, 2003, 'CO', 'Age', '18-24 years', 'Crude Prevalence', 13.1, None, None, 11.6, 14.6, 293.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (888859, 2003, 'CO', 'Age', '25-34 years', 'Crude Prevalence', 19.3, None, None, 17.9, 20.7, 671.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (888860, 2003, 'CO', 'Age', '35-44 years', 'Crude Prevalence', 21.6, None, None, 20.2, 23.0, 862.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (888861, 2003, 'CO', 'Age', '45-54 years', 'Crude Prevalence', 20.4, None, None, 19.1, 21.7, 941.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (888862, 2003, 'CO', 'Age', '55-64 years', 'Crude Prevalence', 12.3, None, None, 11.3, 13.3, 616.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (888863, 2003, 'CO', 'Age', '65+ years', 'Crude Prevalence', 13.3, None, None, 12.2, 14.4, 683.0, 'Overall', 'Overall', 'AGE', 8.0, 8.0)
# (891366, 2003, 'CT', 'Age', '18-24 years', 'Crude Prevalence', 10.0, None, None, 8.8, 11.2, 293.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (891367, 2003, 'CT', 'Age', '25-34 years', 'Crude Prevalence', 16.7, None, None, 15.5, 17.9, 789.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (891368, 2003, 'CT', 'Age', '35-44 years', 'Crude Prevalence', 21.4, None, None, 20.2, 22.6, 1183.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (891369, 2003, 'CT', 'Age', '45-54 years', 'Crude Prevalence', 19.7, None, None, 18.5, 20.9, 1198.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (891370, 2003, 'CT', 'Age', '55-64 years', 'Crude Prevalence', 13.6, None, None, 12.6, 14.6, 784.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (891371, 2003, 'CT', 'Age', '65+ years', 'Crude Prevalence', 18.6, None, None, 17.5, 19.7, 1070.0, 'Overall', 'Overall', 'AGE', 9.0, 9.0)
# (893210, 2003, 'DE', 'Age', '18-24 years', 'Crude Prevalence', 13.1, None, None, 11.3, 14.9, 298.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (893211, 2003, 'DE', 'Age', '25-34 years', 'Crude Prevalence', 16.9, None, None, 15.3, 18.5, 601.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (893212, 2003, 'DE', 'Age', '35-44 years', 'Crude Prevalence', 20.6, None, None, 19.0, 22.2, 845.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (893213, 2003, 'DE', 'Age', '45-54 years', 'Crude Prevalence', 18.4, None, None, 16.8, 20.0, 803.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (893214, 2003, 'DE', 'Age', '55-64 years', 'Crude Prevalence', 13.4, None, None, 12.1, 14.7, 698.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (893215, 2003, 'DE', 'Age', '65+ years', 'Crude Prevalence', 17.6, None, None, 16.2, 19.0, 797.0, 'Overall', 'Overall', 'AGE', 10.0, 10.0)
# (895516, 2003, 'DC', 'Age', '18-24 years', 'Crude Prevalence', 14.5, None, None, 11.8, 17.2, 150.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (895517, 2003, 'DC', 'Age', '25-34 years', 'Crude Prevalence', 21.7, None, None, 19.5, 23.9, 450.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (895518, 2003, 'DC', 'Age', '35-44 years', 'Crude Prevalence', 19.1, None, None, 17.0, 21.2, 403.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (895519, 2003, 'DC', 'Age', '45-54 years', 'Crude Prevalence', 16.9, None, None, 15.0, 18.8, 416.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (895520, 2003, 'DC', 'Age', '55-64 years', 'Crude Prevalence', 12.0, None, None, 10.4, 13.6, 289.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (895521, 2003, 'DC', 'Age', '65+ years', 'Crude Prevalence', 15.7, None, None, 13.8, 17.6, 334.0, 'Overall', 'Overall', 'AGE', 11.0, 11.0)
# (897994, 2003, 'FL', 'Age', '18-24 years', 'Crude Prevalence', 11.1, None, None, 9.4, 12.8, 291.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (897995, 2003, 'FL', 'Age', '25-34 years', 'Crude Prevalence', 15.6, None, None, 13.9, 17.3, 604.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (897996, 2003, 'FL', 'Age', '35-44 years', 'Crude Prevalence', 19.2, None, None, 17.5, 20.9, 825.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (897997, 2003, 'FL', 'Age', '45-54 years', 'Crude Prevalence', 17.4, None, None, 15.9, 18.9, 946.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (897998, 2003, 'FL', 'Age', '55-64 years', 'Crude Prevalence', 13.5, None, None, 12.2, 14.8, 939.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (897999, 2003, 'FL', 'Age', '65+ years', 'Crude Prevalence', 23.2, None, None, 21.5, 24.9, 1433.0, 'Overall', 'Overall', 'AGE', 12.0, 12.0)
# (899976, 2003, 'GA', 'Age', '18-24 years', 'Crude Prevalence', 13.8, None, None, 12.3, 15.3, 582.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (899977, 2003, 'GA', 'Age', '25-34 years', 'Crude Prevalence', 20.0, None, None, 18.7, 21.3, 1238.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (899978, 2003, 'GA', 'Age', '35-44 years', 'Crude Prevalence', 21.9, None, None, 20.6, 23.2, 1475.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (899979, 2003, 'GA', 'Age', '45-54 years', 'Crude Prevalence', 18.7, None, None, 17.6, 19.8, 1683.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (899980, 2003, 'GA', 'Age', '55-64 years', 'Crude Prevalence', 12.3, None, None, 11.4, 13.2, 1240.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (899981, 2003, 'GA', 'Age', '65+ years', 'Crude Prevalence', 13.4, None, None, 12.5, 14.3, 1433.0, 'Overall', 'Overall', 'AGE', 13.0, 13.0)
# (904400, 2003, 'HI', 'Age', '18-24 years', 'Crude Prevalence', 12.4, None, None, 10.9, 13.9, 318.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (904401, 2003, 'HI', 'Age', '25-34 years', 'Crude Prevalence', 17.4, None, None, 16.0, 18.8, 696.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (904402, 2003, 'HI', 'Age', '35-44 years', 'Crude Prevalence', 19.6, None, None, 18.1, 21.1, 828.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (904403, 2003, 'HI', 'Age', '45-54 years', 'Crude Prevalence', 19.2, None, None, 17.8, 20.6, 968.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (904404, 2003, 'HI', 'Age', '55-64 years', 'Crude Prevalence', 13.2, None, None, 11.9, 14.5, 646.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (904405, 2003, 'HI', 'Age', '65+ years', 'Crude Prevalence', 18.3, None, None, 16.9, 19.7, 883.0, 'Overall', 'Overall', 'AGE', 14.0, 14.0)
# (906542, 2003, 'ID', 'Age', '18-24 years', 'Crude Prevalence', 15.3, None, None, 13.8, 16.8, 426.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (906543, 2003, 'ID', 'Age', '25-34 years', 'Crude Prevalence', 17.7, None, None, 16.4, 19.0, 799.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (906544, 2003, 'ID', 'Age', '35-44 years', 'Crude Prevalence', 19.3, None, None, 18.0, 20.6, 958.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (906545, 2003, 'ID', 'Age', '45-54 years', 'Crude Prevalence', 19.1, None, None, 17.8, 20.4, 1036.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (906546, 2003, 'ID', 'Age', '55-64 years', 'Crude Prevalence', 12.7, None, None, 11.7, 13.7, 758.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (906547, 2003, 'ID', 'Age', '65+ years', 'Crude Prevalence', 15.9, None, None, 14.8, 17.0, 1022.0, 'Overall', 'Overall', 'AGE', 15.0, 15.0)
# (908901, 2003, 'IL', 'Age', '18-24 years', 'Crude Prevalence', 13.2, None, None, 11.9, 14.5, 431.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (908902, 2003, 'IL', 'Age', '25-34 years', 'Crude Prevalence', 18.6, None, None, 17.3, 19.9, 871.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (908903, 2003, 'IL', 'Age', '35-44 years', 'Crude Prevalence', 20.5, None, None, 19.3, 21.7, 1138.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (908904, 2003, 'IL', 'Age', '45-54 years', 'Crude Prevalence', 18.6, None, None, 17.4, 19.8, 1042.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (908905, 2003, 'IL', 'Age', '55-64 years', 'Crude Prevalence', 14.2, None, None, 13.2, 15.2, 785.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (908906, 2003, 'IL', 'Age', '65+ years', 'Crude Prevalence', 14.9, None, None, 13.9, 15.9, 1000.0, 'Overall', 'Overall', 'AGE', 16.0, 16.0)
# (911368, 2003, 'IN', 'Age', '18-24 years', 'Crude Prevalence', 13.8, None, None, 12.5, 15.1, 425.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (911369, 2003, 'IN', 'Age', '25-34 years', 'Crude Prevalence', 17.3, None, None, 16.2, 18.4, 897.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (911370, 2003, 'IN', 'Age', '35-44 years', 'Crude Prevalence', 20.0, None, None, 18.8, 21.2, 1074.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (911371, 2003, 'IN', 'Age', '45-54 years', 'Crude Prevalence', 18.9, None, None, 17.8, 20.0, 1148.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (911372, 2003, 'IN', 'Age', '55-64 years', 'Crude Prevalence', 12.9, None, None, 12.0, 13.8, 830.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (911373, 2003, 'IN', 'Age', '65+ years', 'Crude Prevalence', 17.1, None, None, 16.1, 18.1, 1107.0, 'Overall', 'Overall', 'AGE', 17.0, 17.0)
# (913558, 2003, 'IA', 'Age', '18-24 years', 'Crude Prevalence', 14.2, None, None, 12.6, 15.8, 320.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (913559, 2003, 'IA', 'Age', '25-34 years', 'Crude Prevalence', 15.6, None, None, 14.4, 16.8, 667.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (913560, 2003, 'IA', 'Age', '35-44 years', 'Crude Prevalence', 18.6, None, None, 17.4, 19.8, 963.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (913561, 2003, 'IA', 'Age', '45-54 years', 'Crude Prevalence', 18.6, None, None, 17.4, 19.8, 1013.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (913562, 2003, 'IA', 'Age', '55-64 years', 'Crude Prevalence', 12.6, None, None, 11.6, 13.6, 770.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (913563, 2003, 'IA', 'Age', '65+ years', 'Crude Prevalence', 20.4, None, None, 19.2, 21.6, 1270.0, 'Overall', 'Overall', 'AGE', 18.0, 18.0)
# (915346, 2003, 'KS', 'Age', '18-24 years', 'Crude Prevalence', 14.4, None, None, 12.7, 16.1, 285.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (915347, 2003, 'KS', 'Age', '25-34 years', 'Crude Prevalence', 16.7, None, None, 15.5, 17.9, 729.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (915348, 2003, 'KS', 'Age', '35-44 years', 'Crude Prevalence', 19.5, None, None, 18.2, 20.8, 910.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (915349, 2003, 'KS', 'Age', '45-54 years', 'Crude Prevalence', 18.9, None, None, 17.7, 20.1, 1033.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (915350, 2003, 'KS', 'Age', '55-64 years', 'Crude Prevalence', 12.2, None, None, 11.2, 13.2, 620.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (915351, 2003, 'KS', 'Age', '65+ years', 'Crude Prevalence', 18.2, None, None, 17.0, 19.4, 1040.0, 'Overall', 'Overall', 'AGE', 19.0, 19.0)
# (917649, 2003, 'KY', 'Age', '18-24 years', 'Crude Prevalence', 13.2, None, None, 11.6, 14.8, 414.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (917650, 2003, 'KY', 'Age', '25-34 years', 'Crude Prevalence', 17.5, None, None, 16.1, 18.9, 1068.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (917651, 2003, 'KY', 'Age', '35-44 years', 'Crude Prevalence', 19.9, None, None, 18.5, 21.3, 1367.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (917652, 2003, 'KY', 'Age', '45-54 years', 'Crude Prevalence', 18.9, None, None, 17.6, 20.2, 1539.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (917653, 2003, 'KY', 'Age', '55-64 years', 'Crude Prevalence', 13.4, None, None, 12.4, 14.4, 1341.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (917654, 2003, 'KY', 'Age', '65+ years', 'Crude Prevalence', 17.1, None, None, 16.0, 18.2, 1904.0, 'Overall', 'Overall', 'AGE', 20.0, 20.0)
# (920006, 2003, 'LA', 'Age', '18-24 years', 'Crude Prevalence', 15.0, None, None, 13.5, 16.5, 429.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (920007, 2003, 'LA', 'Age', '25-34 years', 'Crude Prevalence', 17.6, None, None, 16.4, 18.8, 792.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (920008, 2003, 'LA', 'Age', '35-44 years', 'Crude Prevalence', 19.8, None, None, 18.5, 21.1, 981.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (920009, 2003, 'LA', 'Age', '45-54 years', 'Crude Prevalence', 18.7, None, None, 17.5, 19.9, 1035.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (920010, 2003, 'LA', 'Age', '55-64 years', 'Crude Prevalence', 12.6, None, None, 11.7, 13.5, 856.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (920011, 2003, 'LA', 'Age', '65+ years', 'Crude Prevalence', 16.3, None, None, 15.2, 17.4, 989.0, 'Overall', 'Overall', 'AGE', 21.0, 21.0)
# (922203, 2003, 'ME', 'Age', '18-24 years', 'Crude Prevalence', 11.6, None, None, 9.6, 13.6, 141.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (922204, 2003, 'ME', 'Age', '25-34 years', 'Crude Prevalence', 14.5, None, None, 12.9, 16.1, 328.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (922205, 2003, 'ME', 'Age', '35-44 years', 'Crude Prevalence', 20.2, None, None, 18.4, 22.0, 500.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (922206, 2003, 'ME', 'Age', '45-54 years', 'Crude Prevalence', 20.5, None, None, 18.7, 22.3, 532.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (922207, 2003, 'ME', 'Age', '55-64 years', 'Crude Prevalence', 14.1, None, None, 12.7, 15.5, 413.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (922208, 2003, 'ME', 'Age', '65+ years', 'Crude Prevalence', 19.2, None, None, 17.5, 20.9, 478.0, 'Overall', 'Overall', 'AGE', 22.0, 22.0)
# (925089, 2003, 'MD', 'Age', '18-24 years', 'Crude Prevalence', 10.7, None, None, 9.2, 12.2, 259.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (925090, 2003, 'MD', 'Age', '25-34 years', 'Crude Prevalence', 17.6, None, None, 16.1, 19.1, 696.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (925091, 2003, 'MD', 'Age', '35-44 years', 'Crude Prevalence', 22.6, None, None, 21.1, 24.1, 1015.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (925092, 2003, 'MD', 'Age', '45-54 years', 'Crude Prevalence', 20.2, None, None, 18.7, 21.7, 955.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (925093, 2003, 'MD', 'Age', '55-64 years', 'Crude Prevalence', 15.1, None, None, 13.9, 16.3, 735.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (925094, 2003, 'MD', 'Age', '65+ years', 'Crude Prevalence', 13.8, None, None, 12.7, 14.9, 775.0, 'Overall', 'Overall', 'AGE', 23.0, 23.0)
# (926751, 2003, 'MA', 'Age', '18-24 years', 'Crude Prevalence', 12.1, None, None, 10.9, 13.3, 497.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (926752, 2003, 'MA', 'Age', '25-34 years', 'Crude Prevalence', 17.2, None, None, 16.1, 18.3, 1419.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (926753, 2003, 'MA', 'Age', '35-44 years', 'Crude Prevalence', 21.2, None, None, 20.1, 22.3, 1662.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (926754, 2003, 'MA', 'Age', '45-54 years', 'Crude Prevalence', 18.9, None, None, 17.8, 20.0, 1574.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (926755, 2003, 'MA', 'Age', '55-64 years', 'Crude Prevalence', 12.8, None, None, 11.9, 13.7, 1053.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (926756, 2003, 'MA', 'Age', '65+ years', 'Crude Prevalence', 17.9, None, None, 16.8, 19.0, 1375.0, 'Overall', 'Overall', 'AGE', 24.0, 24.0)
# (928448, 2003, 'MI', 'Age', '18-24 years', 'Crude Prevalence', 13.1, None, None, 11.4, 14.8, 237.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (928449, 2003, 'MI', 'Age', '25-34 years', 'Crude Prevalence', 17.1, None, None, 15.5, 18.7, 483.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (928450, 2003, 'MI', 'Age', '35-44 years', 'Crude Prevalence', 20.4, None, None, 18.8, 22.0, 655.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (928451, 2003, 'MI', 'Age', '45-54 years', 'Crude Prevalence', 19.6, None, None, 18.2, 21.0, 754.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (928452, 2003, 'MI', 'Age', '55-64 years', 'Crude Prevalence', 13.8, None, None, 12.6, 15.0, 597.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (928453, 2003, 'MI', 'Age', '65+ years', 'Crude Prevalence', 16.0, None, None, 14.8, 17.2, 825.0, 'Overall', 'Overall', 'AGE', 25.0, 25.0)
# (931189, 2003, 'MN', 'Age', '18-24 years', 'Crude Prevalence', 13.4, None, None, 11.8, 15.0, 259.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (931190, 2003, 'MN', 'Age', '25-34 years', 'Crude Prevalence', 16.9, None, None, 15.6, 18.2, 598.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (931191, 2003, 'MN', 'Age', '35-44 years', 'Crude Prevalence', 21.2, None, None, 19.8, 22.6, 832.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (931192, 2003, 'MN', 'Age', '45-54 years', 'Crude Prevalence', 19.5, None, None, 18.2, 20.8, 802.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (931193, 2003, 'MN', 'Age', '55-64 years', 'Crude Prevalence', 12.4, None, None, 11.4, 13.4, 557.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (931194, 2003, 'MN', 'Age', '65+ years', 'Crude Prevalence', 16.6, None, None, 15.5, 17.7, 835.0, 'Overall', 'Overall', 'AGE', 26.0, 26.0)
# (934006, 2003, 'MS', 'Age', '18-24 years', 'Crude Prevalence', 15.4, None, None, 13.7, 17.1, 322.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (934007, 2003, 'MS', 'Age', '25-34 years', 'Crude Prevalence', 17.7, None, None, 16.4, 19.0, 705.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (934008, 2003, 'MS', 'Age', '35-44 years', 'Crude Prevalence', 19.1, None, None, 17.8, 20.4, 833.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (934009, 2003, 'MS', 'Age', '45-54 years', 'Crude Prevalence', 17.9, None, None, 16.7, 19.1, 915.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (934010, 2003, 'MS', 'Age', '55-64 years', 'Crude Prevalence', 12.7, None, None, 11.7, 13.7, 693.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (934011, 2003, 'MS', 'Age', '65+ years', 'Crude Prevalence', 17.1, None, None, 16.0, 18.2, 954.0, 'Overall', 'Overall', 'AGE', 27.0, 27.0)
# (935552, 2003, 'MO', 'Age', '18-24 years', 'Crude Prevalence', 13.2, None, None, 11.4, 15.0, 326.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (935553, 2003, 'MO', 'Age', '25-34 years', 'Crude Prevalence', 16.7, None, None, 15.1, 18.3, 611.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (935554, 2003, 'MO', 'Age', '35-44 years', 'Crude Prevalence', 19.8, None, None, 18.1, 21.5, 773.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (935555, 2003, 'MO', 'Age', '45-54 years', 'Crude Prevalence', 18.6, None, None, 17.1, 20.1, 828.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (935556, 2003, 'MO', 'Age', '55-64 years', 'Crude Prevalence', 13.2, None, None, 11.9, 14.5, 630.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (935557, 2003, 'MO', 'Age', '65+ years', 'Crude Prevalence', 18.5, None, None, 17.1, 19.9, 1084.0, 'Overall', 'Overall', 'AGE', 28.0, 28.0)
# (937878, 2003, 'MT', 'Age', '18-24 years', 'Crude Prevalence', 13.5, None, None, 11.6, 15.4, 245.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (937879, 2003, 'MT', 'Age', '25-34 years', 'Crude Prevalence', 14.8, None, None, 13.2, 16.4, 505.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (937880, 2003, 'MT', 'Age', '35-44 years', 'Crude Prevalence', 18.5, None, None, 16.9, 20.1, 759.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (937881, 2003, 'MT', 'Age', '45-54 years', 'Crude Prevalence', 20.9, None, None, 19.3, 22.5, 958.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (937882, 2003, 'MT', 'Age', '55-64 years', 'Crude Prevalence', 13.9, None, None, 12.6, 15.2, 673.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (937883, 2003, 'MT', 'Age', '65+ years', 'Crude Prevalence', 18.5, None, None, 17.0, 20.0, 884.0, 'Overall', 'Overall', 'AGE', 29.0, 29.0)
# (939457, 2003, 'NE', 'Age', '18-24 years', 'Crude Prevalence', 14.3, None, None, 12.8, 15.8, 355.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (939458, 2003, 'NE', 'Age', '25-34 years', 'Crude Prevalence', 16.8, None, None, 15.6, 18.0, 734.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (939459, 2003, 'NE', 'Age', '35-44 years', 'Crude Prevalence', 19.2, None, None, 18.0, 20.4, 973.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (939460, 2003, 'NE', 'Age', '45-54 years', 'Crude Prevalence', 18.8, None, None, 17.6, 20.0, 987.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (939461, 2003, 'NE', 'Age', '55-64 years', 'Crude Prevalence', 12.2, None, None, 11.3, 13.1, 699.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (939462, 2003, 'NE', 'Age', '65+ years', 'Crude Prevalence', 18.8, None, None, 17.7, 19.9, 1231.0, 'Overall', 'Overall', 'AGE', 30.0, 30.0)
# (942644, 2003, 'NV', 'Age', '18-24 years', 'Crude Prevalence', 11.5, None, None, 9.6, 13.4, 228.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (942645, 2003, 'NV', 'Age', '25-34 years', 'Crude Prevalence', 19.3, None, None, 17.1, 21.5, 481.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (942646, 2003, 'NV', 'Age', '35-44 years', 'Crude Prevalence', 21.2, None, None, 19.1, 23.3, 590.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (942647, 2003, 'NV', 'Age', '45-54 years', 'Crude Prevalence', 18.6, None, None, 16.6, 20.6, 605.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (942648, 2003, 'NV', 'Age', '55-64 years', 'Crude Prevalence', 14.0, None, None, 12.3, 15.7, 469.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (942649, 2003, 'NV', 'Age', '65+ years', 'Crude Prevalence', 15.3, None, None, 13.6, 17.0, 600.0, 'Overall', 'Overall', 'AGE', 31.0, 31.0)
# (944864, 2003, 'NH', 'Age', '18-24 years', 'Crude Prevalence', 12.1, None, None, 10.6, 13.6, 246.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (944865, 2003, 'NH', 'Age', '25-34 years', 'Crude Prevalence', 15.1, None, None, 14.0, 16.2, 703.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (944866, 2003, 'NH', 'Age', '35-44 years', 'Crude Prevalence', 22.1, None, None, 20.8, 23.4, 1104.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (944867, 2003, 'NH', 'Age', '45-54 years', 'Crude Prevalence', 20.9, None, None, 19.7, 22.1, 1242.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (944868, 2003, 'NH', 'Age', '55-64 years', 'Crude Prevalence', 13.6, None, None, 12.6, 14.6, 824.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (944869, 2003, 'NH', 'Age', '65+ years', 'Crude Prevalence', 16.3, None, None, 15.2, 17.4, 923.0, 'Overall', 'Overall', 'AGE', 32.0, 32.0)
# (946673, 2003, 'NJ', 'Age', '18-24 years', 'Crude Prevalence', 10.9, None, None, 10.0, 11.8, 560.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (946674, 2003, 'NJ', 'Age', '25-34 years', 'Crude Prevalence', 16.9, None, None, 16.0, 17.8, 1563.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (946675, 2003, 'NJ', 'Age', '35-44 years', 'Crude Prevalence', 21.7, None, None, 20.8, 22.6, 2482.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (946676, 2003, 'NJ', 'Age', '45-54 years', 'Crude Prevalence', 19.2, None, None, 18.4, 20.0, 2516.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (946677, 2003, 'NJ', 'Age', '55-64 years', 'Crude Prevalence', 13.3, None, None, 12.6, 14.0, 1703.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (946678, 2003, 'NJ', 'Age', '65+ years', 'Crude Prevalence', 17.9, None, None, 17.1, 18.7, 2481.0, 'Overall', 'Overall', 'AGE', 33.0, 33.0)
# (948710, 2003, 'NM', 'Age', '18-24 years', 'Crude Prevalence', 13.9, None, None, 12.4, 15.4, 375.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (948711, 2003, 'NM', 'Age', '25-34 years', 'Crude Prevalence', 17.0, None, None, 15.8, 18.2, 794.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (948712, 2003, 'NM', 'Age', '35-44 years', 'Crude Prevalence', 19.7, None, None, 18.4, 21.0, 993.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (948713, 2003, 'NM', 'Age', '45-54 years', 'Crude Prevalence', 19.4, None, None, 18.2, 20.6, 1199.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (948714, 2003, 'NM', 'Age', '55-64 years', 'Crude Prevalence', 13.2, None, None, 12.2, 14.2, 906.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (948715, 2003, 'NM', 'Age', '65+ years', 'Crude Prevalence', 16.7, None, None, 15.7, 17.7, 1227.0, 'Overall', 'Overall', 'AGE', 34.0, 34.0)
# (951223, 2003, 'NY', 'Age', '18-24 years', 'Crude Prevalence', 12.4, None, None, 11.1, 13.7, 389.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (951224, 2003, 'NY', 'Age', '25-34 years', 'Crude Prevalence', 17.9, None, None, 16.7, 19.1, 882.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (951225, 2003, 'NY', 'Age', '35-44 years', 'Crude Prevalence', 20.8, None, None, 19.5, 22.1, 1109.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (951226, 2003, 'NY', 'Age', '45-54 years', 'Crude Prevalence', 18.5, None, None, 17.3, 19.7, 1187.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (951227, 2003, 'NY', 'Age', '55-64 years', 'Crude Prevalence', 13.0, None, None, 12.0, 14.0, 860.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (951228, 2003, 'NY', 'Age', '65+ years', 'Crude Prevalence', 17.4, None, None, 16.3, 18.5, 1117.0, 'Overall', 'Overall', 'AGE', 35.0, 35.0)
# (953170, 2003, 'NC', 'Age', '18-24 years', 'Crude Prevalence', 13.0, None, None, 11.5, 14.5, 583.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (953171, 2003, 'NC', 'Age', '25-34 years', 'Crude Prevalence', 18.6, None, None, 17.3, 19.9, 1415.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (953172, 2003, 'NC', 'Age', '35-44 years', 'Crude Prevalence', 20.4, None, None, 19.1, 21.7, 1788.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (953173, 2003, 'NC', 'Age', '45-54 years', 'Crude Prevalence', 18.4, None, None, 17.2, 19.6, 1917.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (953174, 2003, 'NC', 'Age', '55-64 years', 'Crude Prevalence', 13.1, None, None, 12.2, 14.0, 1537.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (953175, 2003, 'NC', 'Age', '65+ years', 'Crude Prevalence', 16.4, None, None, 15.4, 17.4, 2215.0, 'Overall', 'Overall', 'AGE', 36.0, 36.0)
# (955623, 2003, 'ND', 'Age', '18-24 years', 'Crude Prevalence', 15.8, None, None, 13.9, 17.7, 236.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (955624, 2003, 'ND', 'Age', '25-34 years', 'Crude Prevalence', 15.4, None, None, 13.9, 16.9, 395.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (955625, 2003, 'ND', 'Age', '35-44 years', 'Crude Prevalence', 18.1, None, None, 16.6, 19.6, 553.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (955626, 2003, 'ND', 'Age', '45-54 years', 'Crude Prevalence', 18.8, None, None, 17.3, 20.3, 666.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (955627, 2003, 'ND', 'Age', '55-64 years', 'Crude Prevalence', 12.0, None, None, 10.9, 13.1, 445.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (955628, 2003, 'ND', 'Age', '65+ years', 'Crude Prevalence', 20.0, None, None, 18.6, 21.4, 731.0, 'Overall', 'Overall', 'AGE', 37.0, 37.0)
# (957945, 2003, 'OH', 'Age', '18-24 years', 'Crude Prevalence', 12.6, None, None, 11.0, 14.2, 304.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (957946, 2003, 'OH', 'Age', '25-34 years', 'Crude Prevalence', 16.9, None, None, 15.4, 18.4, 601.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (957947, 2003, 'OH', 'Age', '35-44 years', 'Crude Prevalence', 19.8, None, None, 18.2, 21.4, 728.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (957948, 2003, 'OH', 'Age', '45-54 years', 'Crude Prevalence', 19.4, None, None, 17.9, 20.9, 851.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (957949, 2003, 'OH', 'Age', '55-64 years', 'Crude Prevalence', 13.5, None, None, 12.3, 14.7, 606.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (957950, 2003, 'OH', 'Age', '65+ years', 'Crude Prevalence', 17.8, None, None, 16.3, 19.3, 734.0, 'Overall', 'Overall', 'AGE', 38.0, 38.0)
# (960123, 2003, 'OK', 'Age', '18-24 years', 'Crude Prevalence', 14.3, None, None, 13.1, 15.5, 528.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (960124, 2003, 'OK', 'Age', '25-34 years', 'Crude Prevalence', 16.9, None, None, 15.9, 17.9, 1064.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (960125, 2003, 'OK', 'Age', '35-44 years', 'Crude Prevalence', 18.8, None, None, 17.8, 19.8, 1384.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (960126, 2003, 'OK', 'Age', '45-54 years', 'Crude Prevalence', 18.3, None, None, 17.3, 19.3, 1483.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (960127, 2003, 'OK', 'Age', '55-64 years', 'Crude Prevalence', 13.3, None, None, 12.5, 14.1, 1252.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (960128, 2003, 'OK', 'Age', '65+ years', 'Crude Prevalence', 18.3, None, None, 17.4, 19.2, 1922.0, 'Overall', 'Overall', 'AGE', 39.0, 39.0)
# (962460, 2003, 'OR', 'Age', '18-24 years', 'Crude Prevalence', 12.8, None, None, 11.3, 14.3, 288.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (962461, 2003, 'OR', 'Age', '25-34 years', 'Crude Prevalence', 17.5, None, None, 16.1, 18.9, 627.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (962462, 2003, 'OR', 'Age', '35-44 years', 'Crude Prevalence', 19.0, None, None, 17.6, 20.4, 729.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (962463, 2003, 'OR', 'Age', '45-54 years', 'Crude Prevalence', 20.1, None, None, 18.7, 21.5, 842.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (962464, 2003, 'OR', 'Age', '55-64 years', 'Crude Prevalence', 13.5, None, None, 12.4, 14.6, 654.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (962465, 2003, 'OR', 'Age', '65+ years', 'Crude Prevalence', 17.1, None, None, 15.9, 18.3, 876.0, 'Overall', 'Overall', 'AGE', 40.0, 40.0)
# (964926, 2003, 'PA', 'Age', '18-24 years', 'Crude Prevalence', 12.2, None, None, 10.7, 13.7, 249.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (964927, 2003, 'PA', 'Age', '25-34 years', 'Crude Prevalence', 15.3, None, None, 13.9, 16.7, 499.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (964928, 2003, 'PA', 'Age', '35-44 years', 'Crude Prevalence', 19.4, None, None, 18.0, 20.8, 766.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (964929, 2003, 'PA', 'Age', '45-54 years', 'Crude Prevalence', 19.1, None, None, 17.7, 20.5, 782.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (964930, 2003, 'PA', 'Age', '55-64 years', 'Crude Prevalence', 15.0, None, None, 13.7, 16.3, 543.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (964931, 2003, 'PA', 'Age', '65+ years', 'Crude Prevalence', 18.9, None, None, 17.6, 20.2, 832.0, 'Overall', 'Overall', 'AGE', 41.0, 41.0)
# (968939, 2003, 'RI', 'Age', '18-24 years', 'Crude Prevalence', 13.5, None, None, 11.7, 15.3, 245.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (968940, 2003, 'RI', 'Age', '25-34 years', 'Crude Prevalence', 16.1, None, None, 14.8, 17.4, 666.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (968941, 2003, 'RI', 'Age', '35-44 years', 'Crude Prevalence', 20.3, None, None, 18.9, 21.7, 865.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (968942, 2003, 'RI', 'Age', '45-54 years', 'Crude Prevalence', 18.7, None, None, 17.3, 20.1, 811.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (968235, 2003, 'RI', 'Age', '55-64 years', 'Crude Prevalence', 12.6, None, None, 11.5, 13.7, 630.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (968236, 2003, 'RI', 'Age', '65+ years', 'Crude Prevalence', 19.0, None, None, 17.6, 20.4, 836.0, 'Overall', 'Overall', 'AGE', 42.0, 42.0)
# (970658, 2003, 'SC', 'Age', '18-24 years', 'Crude Prevalence', 13.8, None, None, 12.4, 15.2, 384.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (970659, 2003, 'SC', 'Age', '25-34 years', 'Crude Prevalence', 17.5, None, None, 16.3, 18.7, 948.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (970660, 2003, 'SC', 'Age', '35-44 years', 'Crude Prevalence', 19.7, None, None, 18.5, 20.9, 1129.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (970661, 2003, 'SC', 'Age', '45-54 years', 'Crude Prevalence', 18.7, None, None, 17.6, 19.8, 1251.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (970662, 2003, 'SC', 'Age', '55-64 years', 'Crude Prevalence', 13.7, None, None, 12.8, 14.6, 999.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (970663, 2003, 'SC', 'Age', '65+ years', 'Crude Prevalence', 16.8, None, None, 15.8, 17.8, 1215.0, 'Overall', 'Overall', 'AGE', 43.0, 43.0)
# (973655, 2003, 'SD', 'Age', '18-24 years', 'Crude Prevalence', 14.8, None, None, 13.2, 16.4, 359.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (973656, 2003, 'SD', 'Age', '25-34 years', 'Crude Prevalence', 15.7, None, None, 14.5, 16.9, 659.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (973657, 2003, 'SD', 'Age', '35-44 years', 'Crude Prevalence', 18.8, None, None, 17.6, 20.0, 988.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (973658, 2003, 'SD', 'Age', '45-54 years', 'Crude Prevalence', 18.7, None, None, 17.5, 19.9, 1057.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (973659, 2003, 'SD', 'Age', '55-64 years', 'Crude Prevalence', 12.1, None, None, 11.2, 13.0, 799.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (973660, 2003, 'SD', 'Age', '65+ years', 'Crude Prevalence', 19.9, None, None, 18.8, 21.0, 1400.0, 'Overall', 'Overall', 'AGE', 44.0, 44.0)
# (975268, 2003, 'TN', 'Age', '18-24 years', 'Crude Prevalence', 12.8, None, None, 10.7, 14.9, 164.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (975925, 2003, 'TN', 'Age', '25-34 years', 'Crude Prevalence', 17.9, None, None, 16.1, 19.7, 390.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (975926, 2003, 'TN', 'Age', '35-44 years', 'Crude Prevalence', 20.0, None, None, 18.2, 21.8, 512.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (975927, 2003, 'TN', 'Age', '45-54 years', 'Crude Prevalence', 18.8, None, None, 17.2, 20.4, 542.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (975928, 2003, 'TN', 'Age', '55-64 years', 'Crude Prevalence', 15.9, None, None, 14.4, 17.4, 468.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (975929, 2003, 'TN', 'Age', '65+ years', 'Crude Prevalence', 14.6, None, None, 13.2, 16.0, 513.0, 'Overall', 'Overall', 'AGE', 45.0, 45.0)
# (977853, 2003, 'TX', 'Age', '18-24 years', 'Crude Prevalence', 14.5, None, None, 13.2, 15.8, 514.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (977854, 2003, 'TX', 'Age', '25-34 years', 'Crude Prevalence', 20.0, None, None, 18.8, 21.2, 1151.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (977855, 2003, 'TX', 'Age', '35-44 years', 'Crude Prevalence', 21.2, None, None, 20.0, 22.4, 1235.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (977856, 2003, 'TX', 'Age', '45-54 years', 'Crude Prevalence', 18.4, None, None, 17.3, 19.5, 1175.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (977857, 2003, 'TX', 'Age', '55-64 years', 'Crude Prevalence', 11.8, None, None, 11.0, 12.6, 874.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (977858, 2003, 'TX', 'Age', '65+ years', 'Crude Prevalence', 14.1, None, None, 13.2, 15.0, 1086.0, 'Overall', 'Overall', 'AGE', 46.0, 46.0)
# (979562, 2003, 'UT', 'Age', '18-24 years', 'Crude Prevalence', 19.0, None, None, 17.0, 21.0, 422.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (979563, 2003, 'UT', 'Age', '25-34 years', 'Crude Prevalence', 23.1, None, None, 21.4, 24.8, 825.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (979564, 2003, 'UT', 'Age', '35-44 years', 'Crude Prevalence', 18.7, None, None, 17.1, 20.3, 774.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (979565, 2003, 'UT', 'Age', '45-54 years', 'Crude Prevalence', 16.5, None, None, 15.0, 18.0, 796.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (979566, 2003, 'UT', 'Age', '55-64 years', 'Crude Prevalence', 10.3, None, None, 9.2, 11.4, 531.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (979567, 2003, 'UT', 'Age', '65+ years', 'Crude Prevalence', 12.3, None, None, 11.1, 13.5, 706.0, 'Overall', 'Overall', 'AGE', 47.0, 47.0)
# (982208, 2003, 'VT', 'Age', '18-24 years', 'Crude Prevalence', 13.4, None, None, 11.7, 15.1, 217.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (982209, 2003, 'VT', 'Age', '25-34 years', 'Crude Prevalence', 14.5, None, None, 13.3, 15.7, 529.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (982210, 2003, 'VT', 'Age', '35-44 years', 'Crude Prevalence', 20.0, None, None, 18.7, 21.3, 917.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (982211, 2003, 'VT', 'Age', '45-54 years', 'Crude Prevalence', 21.0, None, None, 19.7, 22.3, 979.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (982212, 2003, 'VT', 'Age', '55-64 years', 'Crude Prevalence', 13.9, None, None, 12.8, 15.0, 696.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (982213, 2003, 'VT', 'Age', '65+ years', 'Crude Prevalence', 17.1, None, None, 15.9, 18.3, 912.0, 'Overall', 'Overall', 'AGE', 48.0, 48.0)
# (986379, 2003, 'VA', 'Age', '18-24 years', 'Crude Prevalence', 12.8, None, None, 11.3, 14.3, 367.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (986380, 2003, 'VA', 'Age', '25-34 years', 'Crude Prevalence', 17.8, None, None, 16.3, 19.3, 801.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (986381, 2003, 'VA', 'Age', '35-44 years', 'Crude Prevalence', 21.4, None, None, 19.9, 22.9, 1131.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (986382, 2003, 'VA', 'Age', '45-54 years', 'Crude Prevalence', 19.4, None, None, 18.1, 20.7, 1214.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (986383, 2003, 'VA', 'Age', '55-64 years', 'Crude Prevalence', 13.3, None, None, 12.2, 14.4, 909.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (986384, 2003, 'VA', 'Age', '65+ years', 'Crude Prevalence', 15.3, None, None, 14.1, 16.5, 1020.0, 'Overall', 'Overall', 'AGE', 49.0, 49.0)
# (989026, 2003, 'WA', 'Age', '18-24 years', 'Crude Prevalence', 12.9, None, None, 12.1, 13.7, 1411.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (989027, 2003, 'WA', 'Age', '25-34 years', 'Crude Prevalence', 17.8, None, None, 17.1, 18.5, 2722.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (989028, 2003, 'WA', 'Age', '35-44 years', 'Crude Prevalence', 20.8, None, None, 20.1, 21.5, 3560.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (989029, 2003, 'WA', 'Age', '45-54 years', 'Crude Prevalence', 20.1, None, None, 19.4, 20.8, 3961.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (989030, 2003, 'WA', 'Age', '55-64 years', 'Crude Prevalence', 13.0, None, None, 12.4, 13.6, 3056.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (989031, 2003, 'WA', 'Age', '65+ years', 'Crude Prevalence', 15.3, None, None, 14.7, 15.9, 3934.0, 'Overall', 'Overall', 'AGE', 50.0, 50.0)
# (990796, 2003, 'WV', 'Age', '18-24 years', 'Crude Prevalence', 12.4, None, None, 10.7, 14.1, 203.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (990797, 2003, 'WV', 'Age', '25-34 years', 'Crude Prevalence', 15.6, None, None, 14.2, 17.0, 455.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (990798, 2003, 'WV', 'Age', '35-44 years', 'Crude Prevalence', 17.7, None, None, 16.2, 19.2, 557.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (990799, 2003, 'WV', 'Age', '45-54 years', 'Crude Prevalence', 19.5, None, None, 18.0, 21.0, 684.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (990800, 2003, 'WV', 'Age', '55-64 years', 'Crude Prevalence', 14.3, None, None, 13.1, 15.5, 647.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (990801, 2003, 'WV', 'Age', '65+ years', 'Crude Prevalence', 20.5, None, None, 19.1, 21.9, 803.0, 'Overall', 'Overall', 'AGE', 51.0, 51.0)
# (993150, 2003, 'WI', 'Age', '18-24 years', 'Crude Prevalence', 13.6, None, None, 11.8, 15.4, 303.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (993151, 2003, 'WI', 'Age', '25-34 years', 'Crude Prevalence', 16.2, None, None, 14.8, 17.6, 653.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (993152, 2003, 'WI', 'Age', '35-44 years', 'Crude Prevalence', 20.5, None, None, 19.1, 21.9, 870.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (993153, 2003, 'WI', 'Age', '45-54 years', 'Crude Prevalence', 19.3, None, None, 17.9, 20.7, 866.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (993154, 2003, 'WI', 'Age', '55-64 years', 'Crude Prevalence', 12.7, None, None, 11.5, 13.9, 557.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (993155, 2003, 'WI', 'Age', '65+ years', 'Crude Prevalence', 17.7, None, None, 16.4, 19.0, 805.0, 'Overall', 'Overall', 'AGE', 52.0, 52.0)
# (995229, 2003, 'WY', 'Age', '18-24 years', 'Crude Prevalence', 14.6, None, None, 13.0, 16.2, 286.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (995230, 2003, 'WY', 'Age', '25-34 years', 'Crude Prevalence', 15.6, None, None, 14.3, 16.9, 560.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (995231, 2003, 'WY', 'Age', '35-44 years', 'Crude Prevalence', 18.7, None, None, 17.3, 20.1, 712.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (995232, 2003, 'WY', 'Age', '45-54 years', 'Crude Prevalence', 21.2, None, None, 19.9, 22.5, 968.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (995233, 2003, 'WY', 'Age', '55-64 years', 'Crude Prevalence', 13.5, None, None, 12.4, 14.6, 674.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (995234, 2003, 'WY', 'Age', '65+ years', 'Crude Prevalence', 16.3, None, None, 15.1, 17.5, 804.0, 'Overall', 'Overall', 'AGE', 53.0, 53.0)
# (902644, 2003, 'GU', 'Age', '18-24 years', 'Crude Prevalence', 16.2, None, None, 12.9, 19.5, 96.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (902645, 2003, 'GU', 'Age', '25-34 years', 'Crude Prevalence', 23.6, None, None, 20.2, 27.0, 190.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (902646, 2003, 'GU', 'Age', '35-44 years', 'Crude Prevalence', 23.3, None, None, 20.2, 26.4, 222.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (902647, 2003, 'GU', 'Age', '45-54 years', 'Crude Prevalence', 17.1, None, None, 14.3, 19.9, 157.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (902648, 2003, 'GU', 'Age', '55-64 years', 'Crude Prevalence', 11.3, None, None, 8.7, 13.9, 77.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (902649, 2003, 'GU', 'Age', '65+ years', 'Crude Prevalence', 8.4, None, None, 6.2, 10.6, 65.0, 'Overall', 'Overall', 'AGE', 56.0, 56.0)
# (966272, 2003, 'PR', 'Age', '18-24 years', 'Crude Prevalence', 14.8, None, None, 13.1, 16.5, 362.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (966273, 2003, 'PR', 'Age', '25-34 years', 'Crude Prevalence', 19.3, None, None, 17.5, 21.1, 537.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (966274, 2003, 'PR', 'Age', '35-44 years', 'Crude Prevalence', 18.7, None, None, 17.2, 20.2, 813.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (966275, 2003, 'PR', 'Age', '45-54 years', 'Crude Prevalence', 17.0, None, None, 15.6, 18.4, 736.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (966276, 2003, 'PR', 'Age', '55-64 years', 'Crude Prevalence', 13.9, None, None, 12.7, 15.1, 740.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (966277, 2003, 'PR', 'Age', '65+ years', 'Crude Prevalence', 16.4, None, None, 15.1, 17.7, 978.0, 'Overall', 'Overall', 'AGE', 60.0, 60.0)
# (984661, 2003, 'VI', 'Age', '18-24 years', 'Crude Prevalence', 14.8, None, None, 12.0, 17.6, 133.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (984662, 2003, 'VI', 'Age', '25-34 years', 'Crude Prevalence', 19.0, None, None, 16.8, 21.2, 337.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (984663, 2003, 'VI', 'Age', '35-44 years', 'Crude Prevalence', 20.1, None, None, 18.0, 22.2, 489.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (984664, 2003, 'VI', 'Age', '45-54 years', 'Crude Prevalence', 19.6, None, None, 17.4, 21.8, 467.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (984665, 2003, 'VI', 'Age', '55-64 years', 'Crude Prevalence', 13.5, None, None, 11.8, 15.2, 350.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (984552, 2003, 'VI', 'Age', '65+ years', 'Crude Prevalence', 13.2, None, None, 11.2, 15.2, 276.0, 'Overall', 'Overall', 'AGE', 62.0, 62.0)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ...
# (1126356, 2001, 'CT', 'High Blood Pressure', 'No', 'Crude Prevalence', 76.0, None, None, 74.9, 77.1, 5813.0, 'Overall', 'Overall', '_RFHYPE3', 9.0, 9.0)
# (1128687, 2001, 'DE', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 27.2, None, None, 25.3, 29.1, 1042.0, 'Overall', 'Overall', '_RFHYPE3', 10.0, 10.0)
# (1128688, 2001, 'DE', 'High Blood Pressure', 'No', 'Crude Prevalence', 72.8, None, None, 70.9, 74.7, 2469.0, 'Overall', 'Overall', '_RFHYPE3', 10.0, 10.0)
# (1130287, 2001, 'DC', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 29.0, None, None, 26.5, 31.5, 521.0, 'Overall', 'Overall', '_RFHYPE3', 11.0, 11.0)
# (1130288, 2001, 'DC', 'High Blood Pressure', 'No', 'Crude Prevalence', 71.0, None, None, 68.5, 73.5, 1362.0, 'Overall', 'Overall', '_RFHYPE3', 11.0, 11.0)
# (1133375, 2001, 'FL', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.9, None, None, 25.4, 28.4, 1234.0, 'Overall', 'Overall', '_RFHYPE3', 12.0, 12.0)
# (1133376, 2001, 'FL', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.1, None, None, 71.6, 74.6, 3436.0, 'Overall', 'Overall', '_RFHYPE3', 12.0, 12.0)
# (1135658, 2001, 'GA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.9, None, None, 25.3, 28.5, 1280.0, 'Overall', 'Overall', '_RFHYPE3', 13.0, 13.0)
# (1135659, 2001, 'GA', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.1, None, None, 71.5, 74.7, 3244.0, 'Overall', 'Overall', '_RFHYPE3', 13.0, 13.0)
# (1139718, 2001, 'HI', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.1, None, None, 22.4, 25.8, 1085.0, 'Overall', 'Overall', '_RFHYPE3', 14.0, 14.0)
# (1139719, 2001, 'HI', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.9, None, None, 74.2, 77.6, 3405.0, 'Overall', 'Overall', '_RFHYPE3', 14.0, 14.0)
# (1141713, 2001, 'ID', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.6, None, None, 23.1, 26.1, 1236.0, 'Overall', 'Overall', '_RFHYPE3', 15.0, 15.0)
# (1141714, 2001, 'ID', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.4, None, None, 73.9, 76.9, 3587.0, 'Overall', 'Overall', '_RFHYPE3', 15.0, 15.0)
# (1144126, 2001, 'IL', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.8, None, None, 22.8, 26.8, 573.0, 'Overall', 'Overall', '_RFHYPE3', 16.0, 16.0)
# (1144127, 2001, 'IL', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.2, None, None, 73.2, 77.2, 1593.0, 'Overall', 'Overall', '_RFHYPE3', 16.0, 16.0)
# (1146168, 2001, 'IN', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.8, None, None, 24.3, 27.3, 1073.0, 'Overall', 'Overall', '_RFHYPE3', 17.0, 17.0)
# (1146169, 2001, 'IN', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.2, None, None, 72.7, 75.7, 2915.0, 'Overall', 'Overall', '_RFHYPE3', 17.0, 17.0)
# (1148699, 2001, 'IA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.5, None, None, 23.9, 27.1, 1014.0, 'Overall', 'Overall', '_RFHYPE3', 18.0, 18.0)
# (1148700, 2001, 'IA', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.5, None, None, 72.9, 76.1, 2613.0, 'Overall', 'Overall', '_RFHYPE3', 18.0, 18.0)
# (1150838, 2001, 'KS', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 23.9, None, None, 22.5, 25.3, 1121.0, 'Overall', 'Overall', '_RFHYPE3', 19.0, 19.0)
# (1150839, 2001, 'KS', 'High Blood Pressure', 'No', 'Crude Prevalence', 76.1, None, None, 74.7, 77.5, 3467.0, 'Overall', 'Overall', '_RFHYPE3', 19.0, 19.0)
# (1152219, 2001, 'KY', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 30.1, None, None, 28.6, 31.6, 2568.0, 'Overall', 'Overall', '_RFHYPE3', 20.0, 20.0)
# (1152220, 2001, 'KY', 'High Blood Pressure', 'No', 'Crude Prevalence', 69.9, None, None, 68.4, 71.4, 4949.0, 'Overall', 'Overall', '_RFHYPE3', 20.0, 20.0)
# (1155164, 2001, 'LA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 27.6, None, None, 26.2, 29.0, 1440.0, 'Overall', 'Overall', '_RFHYPE3', 21.0, 21.0)
# (1155165, 2001, 'LA', 'High Blood Pressure', 'No', 'Crude Prevalence', 72.4, None, None, 71.0, 73.8, 3556.0, 'Overall', 'Overall', '_RFHYPE3', 21.0, 21.0)
# (1157164, 2001, 'ME', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.2, None, None, 23.4, 27.0, 663.0, 'Overall', 'Overall', '_RFHYPE3', 22.0, 22.0)
# (1157165, 2001, 'ME', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.8, None, None, 73.0, 76.6, 1749.0, 'Overall', 'Overall', '_RFHYPE3', 22.0, 22.0)
# (1159907, 2001, 'MD', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.3, None, None, 24.6, 28.0, 1186.0, 'Overall', 'Overall', '_RFHYPE3', 23.0, 23.0)
# (1159908, 2001, 'MD', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.7, None, None, 72.0, 75.4, 3276.0, 'Overall', 'Overall', '_RFHYPE3', 23.0, 23.0)
# (1161559, 2001, 'MA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 23.6, None, None, 22.5, 24.7, 2072.0, 'Overall', 'Overall', '_RFHYPE3', 24.0, 24.0)
# (1161560, 2001, 'MA', 'High Blood Pressure', 'No', 'Crude Prevalence', 76.4, None, None, 75.3, 77.5, 6525.0, 'Overall', 'Overall', '_RFHYPE3', 24.0, 24.0)
# (1163683, 2001, 'MI', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 27.3, None, None, 25.7, 28.9, 1104.0, 'Overall', 'Overall', '_RFHYPE3', 25.0, 25.0)
# (1163684, 2001, 'MI', 'High Blood Pressure', 'No', 'Crude Prevalence', 72.7, None, None, 71.1, 74.3, 2720.0, 'Overall', 'Overall', '_RFHYPE3', 25.0, 25.0)
# (1166051, 2001, 'MN', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 22.3, None, None, 20.9, 23.7, 971.0, 'Overall', 'Overall', '_RFHYPE3', 26.0, 26.0)
# (1166052, 2001, 'MN', 'High Blood Pressure', 'No', 'Crude Prevalence', 77.7, None, None, 76.3, 79.1, 2988.0, 'Overall', 'Overall', '_RFHYPE3', 26.0, 26.0)
# (1168149, 2001, 'MS', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 31.3, None, None, 29.4, 33.2, 1030.0, 'Overall', 'Overall', '_RFHYPE3', 27.0, 27.0)
# (1168150, 2001, 'MS', 'High Blood Pressure', 'No', 'Crude Prevalence', 68.7, None, None, 66.8, 70.6, 2005.0, 'Overall', 'Overall', '_RFHYPE3', 27.0, 27.0)
# (1170856, 2001, 'MO', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.5, None, None, 24.7, 28.3, 1186.0, 'Overall', 'Overall', '_RFHYPE3', 28.0, 28.0)
# (1170857, 2001, 'MO', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.5, None, None, 71.7, 75.3, 2990.0, 'Overall', 'Overall', '_RFHYPE3', 28.0, 28.0)
# (1172225, 2001, 'MT', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.8, None, None, 24.8, 28.8, 998.0, 'Overall', 'Overall', '_RFHYPE3', 29.0, 29.0)
# (1172226, 2001, 'MT', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.2, None, None, 71.2, 75.2, 2337.0, 'Overall', 'Overall', '_RFHYPE3', 29.0, 29.0)
# (1174954, 2001, 'NE', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 22.6, None, None, 21.1, 24.1, 938.0, 'Overall', 'Overall', '_RFHYPE3', 30.0, 30.0)
# (1174955, 2001, 'NE', 'High Blood Pressure', 'No', 'Crude Prevalence', 77.4, None, None, 75.9, 78.9, 2749.0, 'Overall', 'Overall', '_RFHYPE3', 30.0, 30.0)
# (1176986, 2001, 'NV', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.6, None, None, 23.0, 28.2, 685.0, 'Overall', 'Overall', '_RFHYPE3', 31.0, 31.0)
# (1176987, 2001, 'NV', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.4, None, None, 71.8, 77.0, 1884.0, 'Overall', 'Overall', '_RFHYPE3', 31.0, 31.0)
# (1179435, 2001, 'NH', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 22.8, None, None, 21.4, 24.2, 964.0, 'Overall', 'Overall', '_RFHYPE3', 32.0, 32.0)
# (1179436, 2001, 'NH', 'High Blood Pressure', 'No', 'Crude Prevalence', 77.2, None, None, 75.8, 78.6, 3097.0, 'Overall', 'Overall', '_RFHYPE3', 32.0, 32.0)
# (1181090, 2001, 'NJ', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.1, None, None, 24.7, 27.5, 1590.0, 'Overall', 'Overall', '_RFHYPE3', 33.0, 33.0)
# (1181091, 2001, 'NJ', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.9, None, None, 72.5, 75.3, 4404.0, 'Overall', 'Overall', '_RFHYPE3', 33.0, 33.0)
# (1183165, 2001, 'NM', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 20.0, None, None, 18.5, 21.5, 797.0, 'Overall', 'Overall', '_RFHYPE3', 34.0, 34.0)
# (1183166, 2001, 'NM', 'High Blood Pressure', 'No', 'Crude Prevalence', 80.0, None, None, 78.5, 81.5, 2823.0, 'Overall', 'Overall', '_RFHYPE3', 34.0, 34.0)
# (1185265, 2001, 'NY', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.0, None, None, 24.3, 27.7, 926.0, 'Overall', 'Overall', '_RFHYPE3', 35.0, 35.0)
# (1185266, 2001, 'NY', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.0, None, None, 72.3, 75.7, 2959.0, 'Overall', 'Overall', '_RFHYPE3', 35.0, 35.0)
# (1187607, 2001, 'NC', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 27.2, None, None, 25.5, 28.9, 1743.0, 'Overall', 'Overall', '_RFHYPE3', 36.0, 36.0)
# (1187608, 2001, 'NC', 'High Blood Pressure', 'No', 'Crude Prevalence', 72.8, None, None, 71.1, 74.5, 4454.0, 'Overall', 'Overall', '_RFHYPE3', 36.0, 36.0)
# (1189338, 2001, 'ND', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.1, None, None, 22.3, 25.9, 629.0, 'Overall', 'Overall', '_RFHYPE3', 37.0, 37.0)
# (1189339, 2001, 'ND', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.9, None, None, 74.1, 77.7, 1878.0, 'Overall', 'Overall', '_RFHYPE3', 37.0, 37.0)
# (1192258, 2001, 'OH', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.6, None, None, 24.8, 28.4, 915.0, 'Overall', 'Overall', '_RFHYPE3', 38.0, 38.0)
# (1192259, 2001, 'OH', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.4, None, None, 71.6, 75.2, 2510.0, 'Overall', 'Overall', '_RFHYPE3', 38.0, 38.0)
# (1194805, 2001, 'OK', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 28.5, None, None, 26.8, 30.2, 1451.0, 'Overall', 'Overall', '_RFHYPE3', 39.0, 39.0)
# (1194806, 2001, 'OK', 'High Blood Pressure', 'No', 'Crude Prevalence', 71.5, None, None, 69.8, 73.2, 3089.0, 'Overall', 'Overall', '_RFHYPE3', 39.0, 39.0)
# (1196474, 2001, 'OR', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.9, None, None, 23.1, 26.7, 646.0, 'Overall', 'Overall', '_RFHYPE3', 40.0, 40.0)
# (1196475, 2001, 'OR', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.1, None, None, 73.3, 76.9, 1885.0, 'Overall', 'Overall', '_RFHYPE3', 40.0, 40.0)
# (1198838, 2001, 'PA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 28.1, None, None, 26.5, 29.7, 1059.0, 'Overall', 'Overall', '_RFHYPE3', 41.0, 41.0)
# (1198839, 2001, 'PA', 'High Blood Pressure', 'No', 'Crude Prevalence', 71.9, None, None, 70.3, 73.5, 2598.0, 'Overall', 'Overall', '_RFHYPE3', 41.0, 41.0)
# (1202663, 2001, 'RI', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.4, None, None, 23.8, 27.0, 1062.0, 'Overall', 'Overall', '_RFHYPE3', 42.0, 42.0)
# (1202664, 2001, 'RI', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.6, None, None, 73.0, 76.2, 3047.0, 'Overall', 'Overall', '_RFHYPE3', 42.0, 42.0)
# (1205239, 2001, 'SC', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 28.8, None, None, 27.0, 30.6, 931.0, 'Overall', 'Overall', '_RFHYPE3', 43.0, 43.0)
# (1205240, 2001, 'SC', 'High Blood Pressure', 'No', 'Crude Prevalence', 71.2, None, None, 69.4, 73.0, 2261.0, 'Overall', 'Overall', '_RFHYPE3', 43.0, 43.0)
# (1207725, 2001, 'SD', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.1, None, None, 22.8, 25.4, 1391.0, 'Overall', 'Overall', '_RFHYPE3', 44.0, 44.0)
# (1207726, 2001, 'SD', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.9, None, None, 74.6, 77.2, 3720.0, 'Overall', 'Overall', '_RFHYPE3', 44.0, 44.0)
# (1209772, 2001, 'TN', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 29.3, None, None, 27.4, 31.2, 906.0, 'Overall', 'Overall', '_RFHYPE3', 45.0, 45.0)
# (1209773, 2001, 'TN', 'High Blood Pressure', 'No', 'Crude Prevalence', 70.7, None, None, 68.8, 72.6, 2017.0, 'Overall', 'Overall', '_RFHYPE3', 45.0, 45.0)
# (1211520, 2001, 'TX', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.6, None, None, 24.4, 26.8, 1601.0, 'Overall', 'Overall', '_RFHYPE3', 46.0, 46.0)
# (1211521, 2001, 'TX', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.4, None, None, 73.2, 75.6, 4309.0, 'Overall', 'Overall', '_RFHYPE3', 46.0, 46.0)
# (1213535, 2001, 'UT', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 22.3, None, None, 20.6, 24.0, 832.0, 'Overall', 'Overall', '_RFHYPE3', 47.0, 47.0)
# (1213536, 2001, 'UT', 'High Blood Pressure', 'No', 'Crude Prevalence', 77.7, None, None, 76.0, 79.4, 2818.0, 'Overall', 'Overall', '_RFHYPE3', 47.0, 47.0)
# (1216001, 2001, 'VT', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 21.4, None, None, 20.1, 22.7, 953.0, 'Overall', 'Overall', '_RFHYPE3', 48.0, 48.0)
# (1216002, 2001, 'VT', 'High Blood Pressure', 'No', 'Crude Prevalence', 78.6, None, None, 77.3, 79.9, 3342.0, 'Overall', 'Overall', '_RFHYPE3', 48.0, 48.0)
# (1220110, 2001, 'VA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 25.8, None, None, 24.0, 27.6, 794.0, 'Overall', 'Overall', '_RFHYPE3', 49.0, 49.0)
# (1220111, 2001, 'VA', 'High Blood Pressure', 'No', 'Crude Prevalence', 74.2, None, None, 72.4, 76.0, 2137.0, 'Overall', 'Overall', '_RFHYPE3', 49.0, 49.0)
# (1222820, 2001, 'WA', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.4, None, None, 22.9, 25.9, 1032.0, 'Overall', 'Overall', '_RFHYPE3', 50.0, 50.0)
# (1222821, 2001, 'WA', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.6, None, None, 74.1, 77.1, 3163.0, 'Overall', 'Overall', '_RFHYPE3', 50.0, 50.0)
# (1224191, 2001, 'WV', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 32.5, None, None, 30.7, 34.3, 1070.0, 'Overall', 'Overall', '_RFHYPE3', 51.0, 51.0)
# (1224192, 2001, 'WV', 'High Blood Pressure', 'No', 'Crude Prevalence', 67.5, None, None, 65.7, 69.3, 2020.0, 'Overall', 'Overall', '_RFHYPE3', 51.0, 51.0)
# (1226517, 2001, 'WI', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.1, None, None, 22.5, 25.7, 848.0, 'Overall', 'Overall', '_RFHYPE3', 52.0, 52.0)
# (1226518, 2001, 'WI', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.9, None, None, 74.3, 77.5, 2498.0, 'Overall', 'Overall', '_RFHYPE3', 52.0, 52.0)
# (1228763, 2001, 'WY', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 22.4, None, None, 20.8, 24.0, 719.0, 'Overall', 'Overall', '_RFHYPE3', 53.0, 53.0)
# (1228764, 2001, 'WY', 'High Blood Pressure', 'No', 'Crude Prevalence', 77.6, None, None, 76.0, 79.2, 2313.0, 'Overall', 'Overall', '_RFHYPE3', 53.0, 53.0)
# (1137496, 2001, 'GU', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 24.5, None, None, 21.1, 27.9, 192.0, 'Overall', 'Overall', '_RFHYPE3', 56.0, 56.0)
# (1137497, 2001, 'GU', 'High Blood Pressure', 'No', 'Crude Prevalence', 75.5, None, None, 72.1, 78.9, 678.0, 'Overall', 'Overall', '_RFHYPE3', 56.0, 56.0)
# (1200198, 2001, 'PR', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.4, None, None, 24.7, 28.1, 1360.0, 'Overall', 'Overall', '_RFHYPE3', 60.0, 60.0)
# (1200199, 2001, 'PR', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.6, None, None, 71.9, 75.3, 2869.0, 'Overall', 'Overall', '_RFHYPE3', 60.0, 60.0)
# (1218319, 2001, 'VI', 'High Blood Pressure', 'Yes', 'Crude Prevalence', 26.5, None, None, 24.2, 28.8, 619.0, 'Overall', 'Overall', '_RFHYPE3', 62.0, 62.0)
# (1218320, 2001, 'VI', 'High Blood Pressure', 'No', 'Crude Prevalence', 73.5, None, None, 71.2, 75.8, 1640.0, 'Overall', 'Overall', '_RFHYPE3', 62.0, 62.0)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)

# %%
#### Create a table 
mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
#### Return a list of your system's databases
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)

# %%
#### Insert values into a table
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'Lowstreet 4'),
  ('Amy', 'Apple st 652'),
  ('Hannah', 'Mountain 21'),
  ('Michael', 'Valley 345'),
  ('Sandy', 'Ocean blvd 2'),
  ('Betty', 'Green Grass 1'),
  ('Richard', 'Sky st 331'),
  ('Susan', 'One way 98'),
  ('Vicky', 'Yellow Garden 2'),
  ('Ben', 'Park Lane 38'),
  ('William', 'Central st 954'),
  ('Chuck', 'Main Road 989'),
  ('Viola', 'Sideway 1633')
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
