# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
#from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import numpy as np
#import tensorflow as tf

# %%
import mysql.connector
import config as cnf

mydb = mysql.connector.connect(
  host="final-project.cdjfmodwzyq7.us-east-2.rds.amazonaws.com",
  user=cnf.USERNAME,
  password=cnf.PW,
  database="final_project"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM gym_data")

#myresult = mycursor.fetchall()
gym_df = pd.DataFrame(mycursor.fetchall())
gym_df.columns = [x[0] for x in mycursor.description]
gym_df.head()
# Out:
#         State State Abbreviation Most Gyms in State  Total Population (2016)  \
# 0     Alabama                 AL           CrossFit    268         4,863,300
# 1      Alaska                 AK           CrossFit     46           741,894
# 2     Arizona                 AZ           CrossFit    330         6,931,071
# 3    Arkansas                 AR           CrossFit    134         2,988,248
# 4  California                 CA           CrossFit  1,775        39,250,017
#
#   People Per Gym  Gyms per Capita (100,000)
# 0      18,146.64                       5.51
# 1      16,128.13                       6.20
# 2      21,003.25                       4.76
# 3      22,300.36                       4.48
# 4      22,112.69                       4.52

# %%
mydb = mysql.connector.connect(
  host="final-project.cdjfmodwzyq7.us-east-2.rds.amazonaws.com",
  user=cnf.USERNAME,
  password=cnf.PW,
  database="final_project"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM fast_food_restaurants")

#myresult = mycursor.fetchall()
restaurant_df = pd.DataFrame(mycursor.fetchall())
restaurant_df.columns = [x[0] for x in mycursor.description]
restaurant_df.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# 3        McDonald's      13662       NY
# 4   OMG! Rotisserie      45701       OH
#
#                                             websites
# 0  http://mcdonalds.com,http://www.mcdonalds.com/...
# 1                              http://www.wendys.com
# 2  http://www.frischs.com,https://www.frischs.com...
# 3  http://mcdonalds.com,http://www.mcdonalds.com/...
# 4  http://www.omgrotisserie.com,http://omgrotisse...

# %%
gym_df.rename(columns={'State Abbreviation' : 'province'}, inplace=True)

# %%
gym_df.head()
# Out:
#         State province Most Gyms in State  Total Population (2016)  \
# 0     Alabama       AL           CrossFit    268         4,863,300
# 1      Alaska       AK           CrossFit     46           741,894
# 2     Arizona       AZ           CrossFit    330         6,931,071
# 3    Arkansas       AR           CrossFit    134         2,988,248
# 4  California       CA           CrossFit  1,775        39,250,017
#
#   People Per Gym  Gyms per Capita (100,000)
# 0      18,146.64                       5.51
# 1      16,128.13                       6.20
# 2      21,003.25                       4.76
# 3      22,300.36                       4.48
# 4      22,112.69                       4.52

# %%
rest_count = restaurant_df.groupby(['province'])['name'].count().reset_index()

#	df1.groupby(['State'])['Sales'].count().reset_index()
rest_count.head()
# Out:
#   province  name
# 0       AK    14
# 1       AL   236
# 2       AR   151
# 3       AZ   208
# 4       CA   676

# %%
rest_count.rename(columns={'name' : 'num_restaurants'}, inplace=True)

# %%
mydb = mysql.connector.connect(
  host="final-project.cdjfmodwzyq7.us-east-2.rds.amazonaws.com",
  user=cnf.USERNAME,
  password=cnf.PW,
  database="final_project"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM merged_df")

#myresult = mycursor.fetchall()
merged_df = pd.DataFrame(mycursor.fetchall())
merged_df.columns = [x[0] for x in mycursor.description]
merged_df.head()
# Out:
#          ID    Year LocationAbbr Topic     Response   Data_Value_Type  \
# 0  881138.0  2003.0           US   Age  18-24 years  Crude Prevalence
# 1  881139.0  2003.0           US   Age  25-34 years  Crude Prevalence
# 2  881140.0  2003.0           US   Age  35-44 years  Crude Prevalence
# 3  881141.0  2003.0           US   Age  45-54 years  Crude Prevalence
# 4  881142.0  2003.0           US   Age  55-64 years  Crude Prevalence
#
#    Data_Value Data_Value_Footnote_Symbol  \
# 0        13.4                         **
# 1        17.3                         **
# 2        20.0                         **
# 3        18.9                         **
# 4        13.2                         **
#
#                                  Data_Value_Footnote  Low_Confidence_Limit  \
# 0  Median value reported with no confidence inter...                   NaN
# 1  Median value reported with no confidence inter...                   NaN
# 2  Median value reported with no confidence inter...                   NaN
# 3  Median value reported with no confidence inter...                   NaN
# 4  Median value reported with no confidence inter...                   NaN
#
#    High_Confidence_Limit  Sample_Size Stratification StratificationType  \
# 0                    NaN         54.0        Overall            Overall
# 1                    NaN         54.0        Overall            Overall
# 2                    NaN         54.0        Overall            Overall
# 3                    NaN         54.0        Overall            Overall
# 4                    NaN         54.0        Overall            Overall
#
#   IndicatorId  LocationOrder  ParentStateDisplayOrder
# 0         AGE            1.0                      1.0
# 1         AGE            1.0                      1.0
# 2         AGE            1.0                      1.0
# 3         AGE            1.0                      1.0
# 4         AGE            1.0                      1.0

# %%
diabetes_ave = merged_df.groupby(['LocationAbbr'])['Data_Value'].mean().reset_index()


diabetes_ave.rename(columns={'LocationAbbr' : 'province', 'Data_Value': 'With_Diabetes'}, inplace=True)

diabetes_ave.head()
# Out:
#   province  With_Diabetes
# 0       AK      27.369887
# 1       AL      27.203520
# 2       AR      27.243750
# 3       AZ      27.245032
# 4       CA      27.199680

# %%
restaurant_df.to_csv('restaurant.csv', index = False)

# %%
gym_df.to_csv('gym.csv', index = False)

# %%
joined_df = diabetes_ave.join(rest_count.set_index('province'), on='province')
#joined_data = data_set1.join(data_set2.set_index('Roll_no'), on="Roll_no")
joined_df.head()
# Out:
#   province  With_Diabetes  num_restaurants
# 0       AK      27.369887             14.0
# 1       AL      27.203520            236.0
# 2       AR      27.243750            151.0
# 3       AZ      27.245032            208.0
# 4       CA      27.199680            676.0

# %%
joined_df = joined_df.join(gym_df.set_index('province'), on='province')
joined_df.head()
# Out:
#   province  With_Diabetes  num_restaurants       State Most Gyms in State  \
# 0       AK      27.369887             14.0      Alaska           CrossFit
# 1       AL      27.203520            236.0     Alabama           CrossFit
# 2       AR      27.243750            151.0    Arkansas           CrossFit
# 3       AZ      27.245032            208.0     Arizona           CrossFit
# 4       CA      27.199680            676.0  California           CrossFit
#
#    Total Population (2016) People Per Gym  Gyms per Capita (100,000)
# 0     46           741,894      16,128.13                       6.20
# 1    268         4,863,300      18,146.64                       5.51
# 2    134         2,988,248      22,300.36                       4.48
# 3    330         6,931,071      21,003.25                       4.76
# 4  1,775        39,250,017      22,112.69                       4.52

# %%
joined_df.to_csv('joined.csv', index = False)

# %%
joined_df['Restaurants per Capita 100k'] = joined_df['num_restaurants'] / (joined_df['Population (2016)'] / 1000)
joined_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ed804b67d392> in <module>
# ----> 1 joined_df['Restaurants per Capita 100k'] = joined_df['num_restaurants'] / (joined_df['Population (2016)'] / 1000)
#       2 joined_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     501         lvalues = extract_array(left, extract_numpy=True)
#     502         rvalues = extract_array(right, extract_numpy=True)
# --> 503         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     504
#     505         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
